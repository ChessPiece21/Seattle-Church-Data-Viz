# %% [markdown]
# # Mapping Seattle's Catholic Churches in Python
# Geographic visualization of the different churches in the Archdiocese of Seattle.
#
# Seattle-Churches.csv, the dataset imported to the geographic data, was created by me and web-scraped from the Archdiocese of Seattle's [Parish Finder](https://archseattle.org/parish-finder/). You can also find it, and the geovisualization I made, on [my Kaggle profile](https://www.kaggle.com/datasets/chesspiece99/archdiocese-of-seattle-churches).
#
# The Python package [GeoPy](https://geopy.readthedocs.io/en/stable/) made all this possible.

# %%
# Import Pandas and Nominatim
import pandas as pd
pd.options.display.max_rows = 100

# Read the data frame in as a CSV and preview
church_df = pd.read_csv("Seattle-Churches.csv")
church_df.head(10)
# Out:
#            X           Y                   NAME           ADDRESS     CITY  \
# 0  47.676973 -122.294037      Assumption Church  6201 33rd Ave NE  Seattle
# 1  47.666715 -122.319072      Blessed Sacrament   5050 8th Ave NE  Seattle
# 2  47.616895 -122.340406        Christ Our Hope   1902 2nd Ave NE  Seattle
# 3  47.717100 -122.354404        Christ the King    405 N 117th St  Seattle
# 4  47.540873 -122.376435            Holy Family  9622 20th Ave SW  Seattle
# 5  47.568445 -122.385018            Holy Rosary  4139 42nd Ave SW  Seattle
# 6  47.611976 -122.308628  Immaculate Conception   820 18th Ave NE  Seattle
# 7  47.649343 -122.400488     Our Lady of Fatima  3307 W Dravus St  Seattle
# 8  47.513981 -122.319443    Our Lady of Lourdes  10243 12th Ave S  Seattle
# 9  47.697081 -122.290604   Our Lady of the Lake  8900 35th Ave NE  Seattle
#
#        NEIGHBORHOOD                  LABEL
# 0           Ravenna      Assumption Church
# 1        U-District      Blessed Sacrament
# 2        Pike Place        Christ Our Hope
# 3         Broadview        Christ the King
# 4      White Center            Holy Family
# 5              Alki            Holy Rosary
# 6  Central District  Immaculate Conception
# 7          Interbay     Our Lady of Fatima
# 8        South Park     Our Lady of ourdes
# 9        Maple Leaf   Our Lady of the Lake

# %%
# Import geocoding
# !pip install geopy
from geopy.geocoders import Nominatim
# Out:
# Requirement already satisfied: geopy in c:\users\giaco\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\giaco\anaconda3\lib\site-packages (from geopy) (2.0)

# %%
# Geocode the central location
geolocator = Nominatim(user_agent = "Joe's Church Map", timeout=2)
location = geolocator.geocode("804 9th Ave, Seattle, WA 98104")

# %%
# Print location
location
# Out:
# Location(Saint James Cathedral, 804, 9th Avenue, Central Business District, First Hill, Seattle, King County, Washington, 98104, United States, (47.60767615, -122.32579227764282, 0.0))

# %%
# Install Folium to make maps
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in c:\users\giaco\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\giaco\anaconda3\lib\site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\giaco\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: numpy in c:\users\giaco\anaconda3\lib\site-packages (from folium) (1.20.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\giaco\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\giaco\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\giaco\anaconda3\lib\site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\giaco\anaconda3\lib\site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\giaco\anaconda3\lib\site-packages (from requests->folium) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\giaco\anaconda3\lib\site-packages (from requests->folium) (2.10)

# %%
# Create base map using Folium
church_map = folium.Map(location=[47.60767615, -122.32579227764282], zoom_start=12)

# Visualize map
church_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb8c9f99b33e3ab3aaeb2fdb1c652039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb8c9f99b33e3ab3aaeb2fdb1c652039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb8c9f99b33e3ab3aaeb2fdb1c652039 = L.map(
#                 &quot;map_fb8c9f99b33e3ab3aaeb2fdb1c652039&quot;,
#                 {
#                     center: [47.60767615, -122.32579227764282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e935a2fa4f4cebaa53186790e89be9ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Why I Chose St. James as the Center:
# Aside from it being the obvious nicest church in all of Washington, it's known as the headquarters for the Archdiocese, so I thought it would be fitting to place the cathedral in the center of the map.

# %%
# Creating map makrers from CSV data
def create_map_markers(row, name):
    folium.Marker(location=[row['X'], row['Y']], popup=[row['NAME']]).add_to(church_map)

# Drop all ambiguous or "not found" locations
found_churches = church_df[church_df['ADDRESS'] != 'Not Found']

# %%
# Create 
found_churches.apply(create_map_markers, name = church_map, axis = 1)
church_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb8c9f99b33e3ab3aaeb2fdb1c652039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb8c9f99b33e3ab3aaeb2fdb1c652039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb8c9f99b33e3ab3aaeb2fdb1c652039 = L.map(
#                 &quot;map_fb8c9f99b33e3ab3aaeb2fdb1c652039&quot;,
#                 {
#                     center: [47.60767615, -122.32579227764282],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e935a2fa4f4cebaa53186790e89be9ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#             var marker_026255806bf20e493248f0f5fad6ad75 = L.marker(
#                 [47.6769733, -122.2940371],
#                 {}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#         var popup_47210a77ecff7b19bd84056c0253fe58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50b6e80c428462e39ac8b2f26dccc9e2 = $(`&lt;div id=&quot;html_50b6e80c428462e39ac8b2f26dccc9e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Assumption Church&#x27;]&lt;/div&gt;`)[0];
#                 popup_47210a77ecff7b19bd84056c0253fe58.setContent(html_50b6e80c428462e39ac8b2f26dccc9e2);
#
#
#
#         marker_026255806bf20e493248f0f5fad6ad75.bindPopup(popup_47210a77ecff7b19bd84056c0253fe58)
#         ;
#
#
#
#
#             var marker_f9e9c10470883e840bf30d32102972a5 = L.marker(
#                 [47.66671497, -122.3190718],
#                 {}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#         var popup_31f59ad7e4decde1edb1cecfa43ab90c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e948e85abcc7883403124610837a1bf = $(`&lt;div id=&quot;html_8e948e85abcc7883403124610837a1bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Blessed Sacrament&#x27;]&lt;/div&gt;`)[0];
#                 popup_31f59ad7e4decde1edb1cecfa43ab90c.setContent(html_8e948e85abcc7883403124610837a1bf);
#
#
#
#         marker_f9e9c10470883e840bf30d32102972a5.bindPopup(popup_31f59ad7e4decde1edb1cecfa43ab90c)
#         ;
#
#
#
#
#             var marker_60f43e140711c1e5cef4085c7c38ea0f = L.marker(
#                 [47.61689491, -122.3404062],
#                 {}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#         var popup_7819bf9df7c8cdff3ff5c8b000a8e040 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a459f877918cf9cc2de11fb220aa3728 = $(`&lt;div id=&quot;html_a459f877918cf9cc2de11fb220aa3728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Christ Our Hope&#x27;]&lt;/div&gt;`)[0];
#                 popup_7819bf9df7c8cdff3ff5c8b000a8e040.setContent(html_a459f877918cf9cc2de11fb220aa3728);
#
#
#
#         marker_60f43e140711c1e5cef4085c7c38ea0f.bindPopup(popup_7819bf9df7c8cdff3ff5c8b000a8e040)
#         ;
#
#
#
#
#             var marker_7ed63d718b473a17de0980494888d2a5 = L.marker(
#                 [47.71709999, -122.3544037],
#                 {}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#         var popup_0f89bbf1c972f52ec587abdae3d9517b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b1ed7e2d1919bb8450ea7d6f0ab366a = $(`&lt;div id=&quot;html_3b1ed7e2d1919bb8450ea7d6f0ab366a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Christ the King&#x27;]&lt;/div&gt;`)[0];
#                 popup_0f89bbf1c972f52ec587abdae3d9517b.setContent(html_3b1ed7e2d1919bb8450ea7d6f0ab366a);
#
#
#
#         marker_7ed63d718b473a17de0980494888d2a5.bindPopup(popup_0f89bbf1c972f52ec587abdae3d9517b)
#         ;
#
#
#
#
#             var marker_a4365b7bfd348fac5c50252e722fe2b0 = L.marker(
#                 [47.54087266, -122.3764346],
#                 {}
#             ).addTo(map_fb8c9f99b33e3ab3aaeb2fdb1c652039);
#
#
#         var popup_82c56998157b9bc30e8094e18e3b0ff7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_072ced5f0ab2397c4b1d0e8de13b2b0b = $(`&lt;div id=&quot;html_072ced5f0ab2397c4b1d0e8de13b2b0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Holy Family&#x27;]&lt;/div&gt;`)[0];
#                 popup_82c56998157b9bc30e8094e18e3b0ff7.setContent(html_072ced5f0ab2397c4b1d0e8de13b2b0b);
#
#
#
#         marker_a4365b7bfd348fac5c50252e722fe2b0.bindPopup(popup_82c56998157b9bc30e8094e18e3b0ff7)
#         ;
